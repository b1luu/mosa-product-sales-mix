# %% [markdown]
# # Category Sales Mix\n\nAnalyze percent of total sales by product category and by individual product.\n\n**Data policy:** use local placeholder paths only. Do not load or output raw data here.

# %% [markdown]
# ## Setup

# %%
from pathlib import Path\n\nRAW_DIR = Path("data/raw")\nPROCESSED_DIR = Path("data/processed")\nREPORTS_DIR = Path("reports")\nFIGURES_DIR = Path("figures")

# %% [markdown]
# ## Load data

# %%
# Example placeholder path; replace with real filenames locally.\nexample_export = RAW_DIR / "example.csv"

# %% [markdown]
# ## Compute sales mix

# %%
# TODO: load cleaned data, aggregate by category and product,\n# and compute percent of total sales.

# %% [markdown]
# ## Notes

# %%
# Capture assumptions, data caveats, and validation checks here.
